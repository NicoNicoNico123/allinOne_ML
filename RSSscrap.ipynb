# %%
# !pip install feedparser pandas
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 2.4 MB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-2.0.3-cp311-cp311-macosx_11_0_arm64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 17.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.2 in ./ml_env/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./ml_env/lib/python3.11/site-packages (from pandas) (2023.3)
# Collecting tzdata>=2022.1 (from pandas)
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting numpy>=1.21.0 (from pandas)
#   Downloading numpy-1.25.0-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 25.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: six>=1.5 in ./ml_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=570aedb666418c92197bafeaf97ef166af8c8983b28b09bef3494522ba81baf0
#   Stored in directory: /Users/sing/Library/Caches/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, tzdata, numpy, feedparser, pandas
# Successfully installed feedparser-6.0.10 numpy-1.25.0 pandas-2.0.3 sgmllib3k-1.0.0 tzdata-2023.3

# %%
import feedparser
import pandas as pd
import csv

# %%
# Parse the RSS feed
feed = feedparser.parse('https://biztoc.com/feed')

# Open CSV file
with open('biztoc.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    # Write header
    writer.writerow(["Title", "Paragraph", "Date"])

    # Parse each item in the feed
    for entry in feed.entries:
        title = entry.title
        try:
            # Here I'm assuming that the paragraph you want is the second <p> element in the description
            paragraph = entry.description.split('</p>')[1].split('<p>')[1]
        except IndexError:
            # If there is no second <p> or </p>, set paragraph to a default value
            paragraph = "No second paragraph found"
        date = entry.published
        writer.writerow([title, paragraph, date])

# %%
pd.set_option('display.max_colwidth', None)
df = pd.read_csv('biztoc.csv')

# %%
df
# Out:
#                                                                                                                Title  \
# 0                                                                  Gen Zers make ‘difficult’ employees, managers say
# 1                         Grocers like Kroger, Walmart collect your shopping data. What I found when requesting mine
# 2    Inflation in the 20 countries using the euro falls to 5.5% in June but that won't stop more interest rate hikes
# 3                                                                                     Europe inflation slips to 5.5%
# 4                                   Use a loyalty card or digital coupon when grocery shopping? You're being tracked
# ..                                                                                                               ...
# 288                                                      Never Skip A Korea Pump? Bitcoin Cash Soars 168% in 10 Days
# 289                                                 Mortgage applications steady despite rate rises, says Nationwide
# 290                                            The Most Romantic City in France Is Not Paris, According to This Chef
# 291                                                   HK Pro-Democracy Radio Station Shuts After Bank Account Frozen
# 292                                                              How DYDX may redeem itself after this latest update
#
#                                                                                                                                                                                                                                                                                                     Paragraph  \
# 0      Three-quarters of bosses find Generation Z workers a trifle difficult, a corporate survey has found. A poll of 1,344 managers and business leaders by ResumeBuilder.com found that 74 percent consider Gen Z employees more challenging than older staffers. Pressed for specifics, employers did not…
# 1      When you go grocery shopping, there's something more valuable to your grocer than the money you spend. Each time you use that loyalty card or grocery app, grocers get valuable insight into your spending habits and product preferences. They glean information about your education level, income,…
# 2                                                                                                                                                                      FRANKFURT, Germany -- Inflation in the 20 countries using the euro falls to 5.5% in June but that won't stop more interest rate hikes.
# 3      FRANKFURT, Germany -- Inflation in Europe slid again in June but fell too slowly to offer much relief to shoppers grumbling over price tags or to stop more interest rate hikes that will raise the cost of borrowing across the economy. The annual rate of 5.5% was down from 6.1% in May in the 20…
# 4        Have a loyalty card with a big grocer? Or maybe you’ve downloaded the app to take advantage of savings with digital coupons. Well, chances are it has not only tracked your purchases, but used your shopping habits to glean data about you like your income, education, ethnicity, and the number…
# ..                                                                                                                                                                                                                                                                                                        ...
# 288  price has gone through the roof in recent days. Within the last ten days, the Bitcoin fork has risen by a staggering 168%, temporarily BCH was already up over 200% today. While Bitcoin Cash was still trading at $104 on June 20 and was stuck in a deep bull market that looked bad even compared to…
# 289   However, the building society said the sharp increase in borrowing costs was likely to cause a "significant drag" on activity in the housing market. However, although the cost of borrowing money over longer terms had risen, it had "yet to have the same negative impact on sentiment", Mr Gardner…
# 290                                                                                                                                                                                                                                                                                                       NaN
# 291                                                                                                                                                                                                                                                                                                       NaN
# 292                                                              DYDX’s social dominance has been on the rise for the last few days. This means the token is receiving more attention from potential buyers. However, it is also worth noting that the supply held by top addresses fell in the last 4 weeks.
#
#                               Date
# 0    Fri, 30 Jun 2023 09:42:06 GMT
# 1    Fri, 30 Jun 2023 09:42:05 GMT
# 2    Fri, 30 Jun 2023 09:42:05 GMT
# 3    Fri, 30 Jun 2023 09:42:05 GMT
# 4    Fri, 30 Jun 2023 09:42:05 GMT
# ..                             ...
# 288  Fri, 30 Jun 2023 07:50:06 GMT
# 289  Fri, 30 Jun 2023 07:48:03 GMT
# 290  Fri, 30 Jun 2023 07:44:10 GMT
# 291  Fri, 30 Jun 2023 07:44:10 GMT
# 292  Fri, 30 Jun 2023 07:44:08 GMT
#
# [293 rows x 3 columns]
